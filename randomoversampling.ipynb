# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/pharos/final_data.csv
# /kaggle/input/pharos/pha_map.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/kaggle/input/pharos/final_data.csv")

# %%
y = pd.read_csv("/kaggle/input/pharos/pha_map.csv")

# %%
df
# Out:
#              H    diameter    albedo    rot_per       e      a      q      i  \
# 0         3.33  939.400000  0.090000   9.074170  0.0789  2.767  2.549  10.59
# 1         4.12  513.000000  0.155000   7.813221  0.2302  2.770  2.132  34.93
# 2         5.16  246.596000  0.214000   7.210000  0.2562  2.669  1.985  12.99
# 3         3.22  525.400000  0.422800   5.342128  0.0894  2.362  2.151   7.14
# 4         7.00  106.699000  0.274000  16.806000  0.1874  2.577  2.094   5.36
# ...        ...         ...       ...        ...     ...    ...    ...    ...
# 1311958  26.23  -31.270931  0.116500  10.355228  0.2989  1.412  0.990   5.87
# 1311959  23.36  -22.712515  0.076847  22.010418  0.2517  1.727  1.292  15.82
# 1311960  18.04   -5.177840  0.090914  25.318527  0.2493  2.424  1.820   5.73
# 1311961  18.50   -7.014612  0.090800  26.064191  0.2824  2.336  1.676   8.08
# 1311962  20.40  -16.150109 -0.016394  21.350975  0.6618  2.821  0.954   4.68
#
#              om       w      ma    ad       n     per  moid_ld
# 0         80.25   73.42   60.08  2.99  0.2141  1680.0   616.00
# 1        172.92  310.87   40.60  3.41  0.2138  1680.0   478.00
# 2        169.84  247.74   37.02  3.35  0.2260  1590.0   403.00
# 3        103.71  151.66  169.35  2.57  0.2715  1330.0   443.00
# 4        141.47  359.14  303.40  3.06  0.2383  1510.0   430.00
# ...         ...     ...     ...   ...     ...     ...      ...
# 1311958  185.95  139.87   19.31  1.83  0.5876   613.0     9.53
# 1311959  190.64  154.93    6.06  2.16  0.4344   829.0   117.00
# 1311960   15.03  337.95  252.37  3.03  0.2611  1380.0   318.00
# 1311961  355.23    5.25  231.41  3.00  0.2761  1300.0   262.00
# 1311962  182.81  234.97  130.25  4.69  0.2080  1730.0    14.20
#
# [1311963 rows x 15 columns]

# %%
y
# Out:
#          pha
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 1311958    0
# 1311959    0
# 1311960    0
# 1311961    0
# 1311962    1
#
# [1311963 rows x 1 columns]

# %%
X = df.drop(columns=['albedo', 'rot_per', 'e', 'a', 'q', 'om', 'w', 'ma', 'ad'])

# %%
X.isnull().sum()
# Out:
# H           0
# diameter    0
# i           0
# n           0
# per         0
# moid_ld     0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import HistGradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score, f1_score, roc_curve, ConfusionMatrixDisplay, RocCurveDisplay
from sklearn.metrics import classification_report
from imblearn.metrics import sensitivity_specificity_support
from imblearn.over_sampling import RandomOverSampler

# %% [markdown]
# # Resampling

# %%
ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(X, y)

# %%
X_resampled
# Out:
#              H    diameter      i       n     per   moid_ld
# 0         3.33  939.400000  10.59  0.2141  1680.0  616.0000
# 1         4.12  513.000000  34.93  0.2138  1680.0  478.0000
# 2         5.16  246.596000  12.99  0.2260  1590.0  403.0000
# 3         3.22  525.400000   7.14  0.2715  1330.0  443.0000
# 4         7.00  106.699000   5.36  0.2383  1510.0  430.0000
# ...        ...         ...    ...     ...     ...       ...
# 2619181  21.33  -14.830002  20.66  0.5333   675.0   15.2000
# 2619182  21.30  -19.136258   1.90  0.2446  1470.0    0.0856
# 2619183  19.78   -6.874107  18.27  0.7381   488.0    2.2100
# 2619184  18.71   -0.247624  23.86  0.6917   520.0    6.8500
# 2619185  19.79  -12.870820  11.26  0.2064  1740.0    8.9200
#
# [2619186 rows x 6 columns]

# %%
y_resampled.value_counts()
# Out:
# pha
# 0      1309593
# 1      1309593
# Name: count, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(X_resampled,y_resampled, test_size=0.2, random_state=43)

# %%
X_train.shape
# Out:
# (2095348, 6)

# %%
X_test.shape
# Out:
# (523838, 6)

# %%
y_train.value_counts()
# Out:
# pha
# 1      1048325
# 0      1047023
# Name: count, dtype: int64

# %%
y_test.value_counts()
# Out:
# pha
# 0      262570
# 1      261268
# Name: count, dtype: int64

# %%
# !pip install dask
# Out:
# Requirement already satisfied: dask in /opt/conda/lib/python3.10/site-packages (2024.5.2)
# Requirement already satisfied: click>=8.1 in /opt/conda/lib/python3.10/site-packages (from dask) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /opt/conda/lib/python3.10/site-packages (from dask) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /opt/conda/lib/python3.10/site-packages (from dask) (2024.3.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from dask) (21.3)
# Requirement already satisfied: partd>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from dask) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from dask) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from dask) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /opt/conda/lib/python3.10/site-packages (from dask) (6.11.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata>=4.13.0->dask) (3.17.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->dask) (3.1.1)
# Requirement already satisfied: locket in /opt/conda/lib/python3.10/site-packages (from partd>=1.2.0->dask) (1.0.0)

# %%
# !python -m pip install dask distributed --upgrade
# Out:
# Requirement already satisfied: dask in /opt/conda/lib/python3.10/site-packages (2024.5.2)
# Collecting dask
#   Downloading dask-2024.6.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting distributed
#   Downloading distributed-2024.6.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: click>=8.1 in /opt/conda/lib/python3.10/site-packages (from dask) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /opt/conda/lib/python3.10/site-packages (from dask) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /opt/conda/lib/python3.10/site-packages (from dask) (2024.3.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from dask) (21.3)
# Requirement already satisfied: partd>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from dask) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from dask) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from dask) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /opt/conda/lib/python3.10/site-packages (from dask) (6.11.0)
# Requirement already satisfied: jinja2>=2.10.3 in /opt/conda/lib/python3.10/site-packages (from distributed) (3.1.2)
# Requirement already satisfied: locket>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from distributed) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from distributed) (1.0.7)
# Requirement already satisfied: psutil>=5.7.2 in /opt/conda/lib/python3.10/site-packages (from distributed) (5.9.3)
# Collecting sortedcontainers>=2.0.5 (from distributed)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting tblib>=1.6.0 (from distributed)
#   Downloading tblib-3.0.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: tornado>=6.0.4 in /opt/conda/lib/python3.10/site-packages (from distributed) (6.3.3)
# Requirement already satisfied: urllib3>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from distributed) (1.26.18)
# Collecting zict>=3.0.0 (from distributed)
#   Downloading zict-3.0.0-py2.py3-none-any.whl.metadata (899 bytes)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata>=4.13.0->dask) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2>=2.10.3->distributed) (2.1.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->dask) (3.1.1)
# Downloading dask-2024.6.2-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 16.9 MB/s eta 0:00:0000:0100:01
# Downloading distributed-2024.6.2-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 37.3 MB/s eta 0:00:00
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Downloading tblib-3.0.0-py3-none-any.whl (12 kB)
# Downloading zict-3.0.0-py2.py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: sortedcontainers, zict, tblib, dask, distributed
#   Attempting uninstall: dask
#     Found existing installation: dask 2024.5.2
#     Uninstalling dask-2024.5.2:
#       Successfully uninstalled dask-2024.5.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-expr 1.1.2 requires dask==2024.5.2, but you have dask 2024.6.2 which is incompatible.
# Successfully installed dask-2024.6.2 distributed-2024.6.2 sortedcontainers-2.4.0 tblib-3.0.0 zict-3.0.0

# %%
from dask.distributed import Client
client = Client(n_workers=16)
client
# Out:
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.5.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# <Client: 'tcp://127.0.0.1:42277' processes=16 threads=16, memory=30.00 GiB>

# %%
import joblib

# %% [markdown]
# # Training with Random forest

# %%
y_train = y_train.squeeze()
y_train
# Out:
# 1205167    0
# 575514     0
# 1212305    0
# 1847891    1
# 1411332    1
#           ..
# 1106227    0
# 1525776    1
# 1439802    1
# 2484501    1
# 1613617    1
# Name: pha, Length: 2095348, dtype: int64

# %%
y_train.value_counts()
# Out:
# pha
# 1    1048325
# 0    1047023
# Name: count, dtype: int64

# %%
rf = RandomForestClassifier()
with joblib.parallel_backend("dask", scatter=[X_train,y_train]):
    rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
# Out:
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9999828191158335

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[262561,      9],
#        [     0, 261268]])

# %%
print(classification_report_imbalanced(y_test,y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       1.00      1.00      1.00      1.00      1.00      1.00    262570
#           1       1.00      1.00      1.00      1.00      1.00      1.00    261268
#
# avg / total       1.00      1.00      1.00      1.00      1.00      1.00    523838

# %%
print(sensitivity_specificity_support(y_test, y_pred))
# Out:
# (array([0.99996572, 1.        ]), array([1.        , 0.99996572]), array([262570, 261268]))

# %%
from sklearn.model_selection import RandomizedSearchCV

model = RandomForestClassifier()

param_grid = {
    'n_estimators': [100, 200, 300, 500],
    'max_depth': [None, 20, 30, 50]
}

rand = RandomizedSearchCV(model, param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# %%
with joblib.parallel_backend("dask", scatter=[X_train,y_train]):
    rand.fit(X_train,y_train)
# Out:
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))

# %%
rand.best_params_
# Out:
# {'n_estimators': 100, 'max_depth': 30}

# %%
rand.best_score_
# Out:
# 0.9999799555932304

# %%
##Training with best parameters
rfbest = RandomForestClassifier(n_estimators= 100, max_depth= 30)
with joblib.parallel_backend("dask", scatter=[X_train,y_train]):
    rfbest.fit(X_train,y_train)
# Out:
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))

# %%
y_pred = rfbest.predict(X_test)

# %%
from imblearn.metrics import classification_report_imbalanced

# %%
print(classification_report_imbalanced(y_test,y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       1.00      1.00      1.00      1.00      1.00      1.00    262570
#           1       1.00      1.00      1.00      1.00      1.00      1.00    261268
#
# avg / total       1.00      1.00      1.00      1.00      1.00      1.00    523838

# %%
##Plotting Confusion matrix

cm = confusion_matrix(y_test, y_pred, labels=rfbest.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=rfbest.classes_)
disp.plot()
plt.show()

# %%
##Plotting ROC Curve

ax = plt.gca()
roc_display = RocCurveDisplay.from_estimator(rfbest, X_test, y_test, ax=ax, alpha=0.8)
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.show()

# %%
print(sensitivity_specificity_support(y_test, y_pred))
# Out:
# (array([0.99997334, 1.        ]), array([1.        , 0.99997334]), array([262570, 261268]))

# %%
print(sensitivity_specificity_support(y_test, y_pred, average='macro'))
# Out:
# (0.9999866702212743, 0.9999866702212743, None)

# %%
print(sensitivity_specificity_support(y_test, y_pred, average='micro'))
# Out:
# (0.9999866370900927, 0.9999866370900927, None)

# %%
print(sensitivity_specificity_support(y_test, y_pred, average='weighted'))
# Out:
# (0.9999866370900927, 0.999986703352456, None)

# %% [markdown]
# # Training with XGBoost

# %%
xgb = XGBClassifier()
with joblib.parallel_backend("dask", scatter=[X_train,y_train]):
    xgb.fit(X_train,y_train)

# %%
y_pred = xgb.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9999713651930559

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[262555,     15],
#        [     0, 261268]])

# %%
roc_auc_score(y_test,y_pred)
# Out:
# 0.999971436188445

# %%
xgb = XGBClassifier()
param_grid = {
    'objective' : [None, 'binary:logistic', 'binary:hinge'],
    'max_depth': [None, 20, 30, 50],
    'eta' : [0.0001, 0.001, 0.01, 0.1, 1],
    'tree_method' : ['auto', 'exact']
}

rand2 = RandomizedSearchCV(xgb, param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# %%
with joblib.parallel_backend("dask", scatter=[X_train,y_train]):
    rand2.fit(X_train,y_train)
# Out:
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))

# %%
rand2.best_params_
# Out:
# {'tree_method': 'exact', 'objective': None, 'max_depth': 20, 'eta': 0.1}

# %%
rand2.best_score_
# Out:
# 0.9999794783505477

# %%
##Training with best parameters
xgbest = XGBClassifier(tree_method='exact',
 objective= None,
 max_depth=20,
 eta=0.1)
xgbest.fit(X_train,y_train)
y_pred = xgbest.predict(X_test)

# %%
print(classification_report_imbalanced(y_test,y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       1.00      1.00      1.00      1.00      1.00      1.00    262570
#           1       1.00      1.00      1.00      1.00      1.00      1.00    261268
#
# avg / total       1.00      1.00      1.00      1.00      1.00      1.00    523838

# %%
##Plotting Confusion matrix

cm = confusion_matrix(y_test, y_pred, labels=xgbest.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=xgbest.classes_)
disp.plot()
plt.show()

# %%
##Plotting ROC Curve

ax = plt.gca()
roc_display = RocCurveDisplay.from_estimator(xgbest, X_test, y_test, ax=ax, alpha=0.8)
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.show()

# %%
print(sensitivity_specificity_support(y_test, y_pred))
# Out:
# (array([0.99996572, 1.        ]), array([1.        , 0.99996572]), array([262570, 261268]))

# %%
print(sensitivity_specificity_support(y_test, y_pred, average='macro'))
# Out:
# (0.999982861713067, 0.999982861713067, None)

# %%
print(sensitivity_specificity_support(y_test, y_pred, average='micro'))
# Out:
# (0.9999828191158335, 0.9999828191158335, None)

# %%
print(sensitivity_specificity_support(y_test, y_pred, average='weighted'))
# Out:
# (0.9999828191158335, 0.9999829043103005, None)

# %% [markdown]
# # Training with LightGBM

# %%
lgb = LGBMClassifier()
lgb.fit(X_train,y_train)
# Out:
# [LightGBM] [Info] Number of positive: 1048325, number of negative: 1047023
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.194818 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 2095348, number of used features: 6
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500311 -> initscore=0.001243
# [LightGBM] [Info] Start training from score 0.001243
# LGBMClassifier()

# %%
y_pred = lgb.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9999847281029631

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[262562,      8],
#        [     0, 261268]])

# %%
roc_auc_score(y_test,y_pred)
# Out:
# 0.9999847659671707

# %%
param_grid = {
    'num_leaves': [30, 50, 70],
    'num_iterations': [100, 200, 300, 500],
    'max_depth': [None, 20, 30, 50],
    'learning_rate' : [0.0001, 0.001, 0.01, 0.1, 1],
}

rand3 = RandomizedSearchCV(lgb, param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# %%
with joblib.parallel_backend("dask", scatter=[X_train,y_train]):
    rand3.fit(X_train,y_train)
# Out:
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Info] Number of positive: 838660, number of negative: 837618
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 1.790067 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 1676278, number of used features: 6
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500311 -> initscore=0.001243
# [LightGBM] [Info] Start training from score 0.001243
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Info] Number of positive: 838660, number of negative: 837618
# [LightGBM] [Info] Number of positive: 838660, number of negative: 837618
# [LightGBM] [Info] Number of positive: 838660, number of negative: 837618
# [LightGBM] [Info] Number of positive: 838660, number of negative: 837618
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.271009 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 1676278, number of used features: 6
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.168934 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 1676278, number of used features: 6
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.189229 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 1676278, number of used features: 6
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500311 -> initscore=0.001243
# [LightGBM] [Info] Start training from score 0.001243
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500311 -> initscore=0.001243
# [LightGBM] [Info] Start training from score 0.001243
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500311 -> initscore=0.001243
# [LightGBM] [Info] Start training from score 0.001243
# [LightGBM] [Info] Number of positive: 838660, number of negative: 837619
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.119948 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 1676278, number of used features: 6
# [LightGBM] [Info] Number of positive: 838660, number of negative: 837618
# [LightGBM] [Info] Number of positive: 838660, number of negative: 837618
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500311 -> initscore=0.001243
# [LightGBM] [Info] Start training from score 0.001243
# [LightGBM] [Info] Number of positive: 838660, number of negative: 837619
# [LightGBM] [Info] Number of positive: 838660, number of negative: 837619
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.367380 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 1676279, number of used features: 6
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.288165 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 1676278, number of used features: 6
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500311 -> initscore=0.001242
# [LightGBM] [Info] Start training from score 0.001242
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.109568 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 1676278, number of used features: 6
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500311 -> initscore=0.001243
# [LightGBM] [Info] Start training from score 0.001243
# [LightGBM] [Info] Number of positive: 838660, number of negative: 837619
# [LightGBM] [Info] Number of positive: 838660, number of negative: 837618
# [LightGBM] [Info] Number of positive: 838660, number of negative: 837618
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.177365 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 1676279, number of used features: 6
# [LightGBM] [Info] Number of positive: 838660, number of negative: 837618
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500311 -> initscore=0.001243
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.083016 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 1676279, number of used features: 6
# [LightGBM] [Info] Start training from score 0.001243
# [LightGBM] [Info] Number of positive: 838660, number of negative: 837619
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500311 -> initscore=0.001242
# [LightGBM] [Info] Start training from score 0.001242
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500311 -> initscore=0.001242
# [LightGBM] [Info] Start training from score 0.001242
# [LightGBM] [Info] Number of positive: 838660, number of negative: 837619
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.121991 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 1676279, number of used features: 6
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.250436 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 1676278, number of used features: 6
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.160831 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 1676278, number of used features: 6
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500311 -> initscore=0.001242
# [LightGBM] [Info] Start training from score 0.001242
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.112195 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 1676278, number of used features: 6
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500311 -> initscore=0.001243
# [LightGBM] [Info] Start training from score 0.001243
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.184842 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 1676279, number of used features: 6
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500311 -> initscore=0.001243
# [LightGBM] [Info] Start training from score 0.001243
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500311 -> initscore=0.001243
# [LightGBM] [Info] Start training from score 0.001243
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500311 -> initscore=0.001242
# [LightGBM] [Info] Start training from score 0.001242
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.270814 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 1676279, number of used features: 6
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500311 -> initscore=0.001242
# [LightGBM] [Info] Start training from score 0.001242
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Info] Number of positive: 1048325, number of negative: 1047023
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.290132 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 2095348, number of used features: 6
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500311 -> initscore=0.001243
# [LightGBM] [Info] Start training from score 0.001243
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
rand3.best_params_
# Out:
# {'num_leaves': 70,
#  'num_iterations': 300,
#  'max_depth': None,
#  'learning_rate': 0.1}

# %%
rand3.best_score_
# Out:
# 0.9999809100877062

# %%
##Training with best parameters
lgbest = LGBMClassifier(num_leaves= 70,
 num_iterations= 300,
 max_depth= None,
 learning_rate= 0.1)
lgbest.fit(X_train,y_train)
y_pred = lgbest.predict(X_test)
# Out:
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Info] Number of positive: 1048325, number of negative: 1047023
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.279381 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 2095348, number of used features: 6
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500311 -> initscore=0.001243
# [LightGBM] [Info] Start training from score 0.001243
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
print(classification_report_imbalanced(y_test,y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       1.00      1.00      1.00      1.00      1.00      1.00    262570
#           1       1.00      1.00      1.00      1.00      1.00      1.00    261268
#
# avg / total       1.00      1.00      1.00      1.00      1.00      1.00    523838

# %%
##Plotting Confusion matrix

cm = confusion_matrix(y_test, y_pred, labels=lgbest.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=lgbest.classes_)
disp.plot()
plt.show()

# %%
##Plotting ROC Curve

ax = plt.gca()
roc_display = RocCurveDisplay.from_estimator(lgbest, X_test, y_test, ax=ax, alpha=0.8)
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.show()

# %%
print(sensitivity_specificity_support(y_test, y_pred))
# Out:
# (array([0.99997715, 1.        ]), array([1.        , 0.99997715]), array([262570, 261268]))

# %%
print(sensitivity_specificity_support(y_test, y_pred, average='macro'))
# Out:
# (0.999988574475378, 0.999988574475378, None)

# %%
print(sensitivity_specificity_support(y_test, y_pred, average='micro'))
# Out:
# (0.9999885460772223, 0.9999885460772223, None)

# %%
print(sensitivity_specificity_support(y_test, y_pred, average='weighted'))
# Out:
# (0.9999885460772223, 0.9999886028735336, None)

# %% [markdown]
# # Training with HistGredientBoosting

# %%
histgb = HistGradientBoostingClassifier()
histgb.fit(X_train,y_train)
y_pred = histgb.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9999904550643519

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[262565,      5],
#        [     0, 261268]])

# %%
roc_auc_score(y_test,y_pred)
# Out:
# 0.9999904787294817

# %%
param_grid = {
    'max_iter': [100, 200, 300, 500],
    'max_depth': [None, 20, 30, 50],
    'learning_rate' : [0.0001, 0.001, 0.01, 0.1, 1]
}

rand4 = RandomizedSearchCV(histgb, param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# %%
with joblib.parallel_backend("dask", scatter=[X_train,y_train]):
    rand4.fit(X_train,y_train)

# %%
rand4.best_params_
# Out:
# {'max_iter': 100, 'max_depth': 20, 'learning_rate': 0.1}

# %%
rand4.best_score_
# Out:
# 0.9999756603646726

# %%
##Training with best parameters
histbest = HistGradientBoostingClassifier(max_iter=100, max_depth=20, learning_rate=0.1)
histbest.fit(X_train,y_train)
y_pred = histbest.predict(X_test)

# %%
print(classification_report_imbalanced(y_test,y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       1.00      1.00      1.00      1.00      1.00      1.00    262570
#           1       1.00      1.00      1.00      1.00      1.00      1.00    261268
#
# avg / total       1.00      1.00      1.00      1.00      1.00      1.00    523838

# %%
##Plotting Confusion matrix

cm = confusion_matrix(y_test, y_pred, labels=histbest.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=histbest.classes_)
disp.plot()
plt.show()

# %%
##Plotting ROC Curve

ax = plt.gca()
roc_display = RocCurveDisplay.from_estimator(histbest, X_test, y_test, ax=ax, alpha=0.8)
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.show()

# %%
print(sensitivity_specificity_support(y_test, y_pred))
# Out:
# (array([0.99996191, 1.        ]), array([1.        , 0.99996191]), array([262570, 261268]))

# %%
print(sensitivity_specificity_support(y_test, y_pred, average='macro'))
# Out:
# (0.9999809574589633, 0.9999809574589633, None)

# %%
print(sensitivity_specificity_support(y_test, y_pred, average='micro'))
# Out:
# (0.9999809101287039, 0.9999809101287039, None)

# %%
print(sensitivity_specificity_support(y_test, y_pred, average='weighted'))
# Out:
# (0.9999809101287039, 0.9999810047892228, None)

# %% [markdown]
# # Training with Adaboost

# %%
abc = AdaBoostClassifier()
abc.fit(X_train,y_train)
y_pred = abc.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9998472810296313

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[262490,     80],
#        [     0, 261268]])

# %%
roc_auc_score(y_test,y_pred)
# Out:
# 0.9998476596717065

# %%
abc = AdaBoostClassifier()
param_grid = {
    'n_estimators' : [100, 200, 300, 500],
    'learning_rate' : [0.0001, 0.001, 0.01, 0.1, 1],
}

rand5 = RandomizedSearchCV(abc, param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# %%
with joblib.parallel_backend("dask", scatter=[X_train,y_train]):
    rand5.fit(X_train,y_train)
# Out:
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1394: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------+-----------+----------+
# | Package | Client   | Scheduler | Workers  |
# +---------+----------+-----------+----------+
# | dask    | 2024.6.2 | 2024.5.2  | 2024.6.2 |
# +---------+----------+-----------+----------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 2
#       1 with joblib.parallel_backend("dask", scatter=[X_train,y_train]):
# ----> 2     rand5.fit(X_train,y_train)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_search.py:909, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     907 refit_start_time = time.time()
#     908 if y is not None:
# --> 909     self.best_estimator_.fit(X, y, **fit_params)
#     910 else:
#     911     self.best_estimator_.fit(X, **fit_params)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:162, in BaseWeightBoosting.fit(self, X, y, sample_weight)
#     159 sample_weight[zero_weight_mask] = 0.0
#     161 # Boosting step
# --> 162 sample_weight, estimator_weight, estimator_error = self._boost(
#     163     iboost, X, y, sample_weight, random_state
#     164 )
#     166 # Early termination
#     167 if sample_weight is None:
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:569, in AdaBoostClassifier._boost(self, iboost, X, y, sample_weight, random_state)
#     530 """Implement a single boost.
#     531
#     532 Perform a single boost according to the real multi-class SAMME.R
#    (...)
#     566     If None then boosting has terminated early.
#     567 """
#     568 if self.algorithm == "SAMME.R":
# --> 569     return self._boost_real(iboost, X, y, sample_weight, random_state)
#     571 else:  # elif self.algorithm == "SAMME":
#     572     return self._boost_discrete(iboost, X, y, sample_weight, random_state)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:608, in AdaBoostClassifier._boost_real(self, iboost, X, y, sample_weight, random_state)
#     606 classes = self.classes_
#     607 y_codes = np.array([-1.0 / (n_classes - 1), 1.0])
# --> 608 y_coding = y_codes.take(classes == y[:, np.newaxis])
#     610 # Displace zero probabilities so the log is defined.
#     611 # Also fix negative elements which may occur with
#     612 # negative sample weights.
#     613 proba = y_predict_proba  # alias for readability
#
# KeyboardInterrupt:
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 1019, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/conda/lib/python3.10/site-packages/distributed/compatibility.py", line 239, in asyncio_run
#     _cancel_all_tasks(loop)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/compatibility.py", line 255, in _cancel_all_tasks
#     loop.run_until_complete(asyncio.gather(*to_cancel, return_exceptions=True))
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/opt/conda/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.10/site-packages/tornado/ioloop.py", line 685, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/opt/conda/lib/python3.10/site-packages/tornado/ioloop.py", line 738, in _run_callback
#     ret = callback()
#   File "/opt/conda/lib/python3.10/site-packages/tornado/ioloop.py", line 762, in _discard_future_result
#     future.result()
#   File "/opt/conda/lib/python3.10/site-packages/tornado/ioloop.py", line 925, in _run
#     self._schedule_next()
#   File "/opt/conda/lib/python3.10/site-packages/tornado/ioloop.py", line 930, in _schedule_next
#     self._timeout = self.io_loop.add_timeout(self._next_timeout, self._run)
#   File "/opt/conda/lib/python3.10/site-packages/tornado/ioloop.py", line 576, in add_timeout
#     return self.call_at(deadline, callback, *args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 206, in call_at
#     return self.asyncio_loop.call_later(
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 721, in call_later
#     timer = self.call_at(self.time() + delay, callback, *args,
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 736, in call_at
#     timer = events.TimerHandle(when, callback, args, self, context)
#   File "/opt/conda/lib/python3.10/asyncio/events.py", line 103, in __init__
#     def __init__(self, when, callback, args, loop, context=None):
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 1019, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/conda/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 1019, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/conda/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 1019, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/conda/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 1019, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/conda/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 1019, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/conda/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 1019, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/conda/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 1019, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/conda/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 1019, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/conda/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 1019, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/conda/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 1019, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/conda/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/opt/conda/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.10/site-packages/tornado/ioloop.py", line 747, in _run_callback
#     ret = gen.convert_yielded(ret)
#   File "/opt/conda/lib/python3.10/functools.py", line 889, in wrapper
#     return dispatch(args[0].__class__)(*args, **kw)
#   File "/opt/conda/lib/python3.10/site-packages/tornado/gen.py", line 873, in convert_yielded
#     elif isinstance(yielded, (list, dict)):
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 1019, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/conda/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 1019, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/conda/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 1019, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/conda/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 1019, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/conda/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 1019, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/conda/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# sys:1: RuntimeWarning: coroutine 'PeriodicCallback._run' was never awaited
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
rand5.best_params_
# Out:
# {'n_estimators': 500, 'learning_rate': 1}

# %%
rand5.best_score_
# Out:
# 0.9999427302733681

# %%
##Training with best parameters
adabest = AdaBoostClassifier(n_estimators=500, learning_rate=1)
with joblib.parallel_backend("dask", scatter=[X_train,y_train]):
    adabest.fit(X_train,y_train)

y_pred = adabest.predict(X_test)

# %%
print(classification_report_imbalanced(y_test,y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       1.00      1.00      1.00      1.00      1.00      1.00    262570
#           1       1.00      1.00      1.00      1.00      1.00      1.00    261268
#
# avg / total       1.00      1.00      1.00      1.00      1.00      1.00    523838

# %%
##Plotting Confusion matrix

cm = confusion_matrix(y_test, y_pred, labels=adabest.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=adabest.classes_)
disp.plot()
plt.show()

# %%
##Plotting ROC Curve

ax = plt.gca()
roc_display = RocCurveDisplay.from_estimator(adabest, X_test, y_test, ax=ax, alpha=0.8)
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.show()

# %%
print(sensitivity_specificity_support(y_test, y_pred))
# Out:
# (array([0.9999086, 1.       ]), array([1.       , 0.9999086]), array([262570, 261268]))

# %%
print(sensitivity_specificity_support(y_test, y_pred, average='macro'))
# Out:
# (0.9999542979015119, 0.9999542979015119, None)

# %%
print(sensitivity_specificity_support(y_test, y_pred, average='micro'))
# Out:
# (0.9999541843088894, 0.9999541843088894, None)

# %%
print(sensitivity_specificity_support(y_test, y_pred, average='weighted'))
# Out:
# (0.9999541843088894, 0.9999544114941346, None)
